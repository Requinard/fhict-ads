# %%
import pandas as pd
import numpy as np
import matplotlib

# %matplotlib inline

# %%
df = pd.read_csv('data.csv')
print(df)
# Out:
#              date  l_ipn  r_asn   f
# 0      2006-07-01      0    701   1
# 1      2006-07-01      0    714   1
# 2      2006-07-01      0   1239   1
# 3      2006-07-01      0   1680   1
# 4      2006-07-01      0   2514   1
# 5      2006-07-01      0   3320   1
# 6      2006-07-01      0   3561  13
# 7      2006-07-01      0   4134   3
# 8      2006-07-01      0   5617   2
# 9      2006-07-01      0   6478   1
# 10     2006-07-01      0   6713   1
# 11     2006-07-01      0   7132   1
# 12     2006-07-01      0   9105   1
# 13     2006-07-01      0  10738   1
# 14     2006-07-01      0  10994   1
# 15     2006-07-01      0  12334   1
# 16     2006-07-01      0  12524   1
# 17     2006-07-01      0  12542   1
# 18     2006-07-01      0  13343   1
# 19     2006-07-01      0  13446   1
# 20     2006-07-01      0  13462  20
# 21     2006-07-01      0  13867   1
# 22     2006-07-01      0  13989   1
# 23     2006-07-01      0  14501  37
# 24     2006-07-01      0  16755   1
# 25     2006-07-01      0  17228   1
# 26     2006-07-01      0  19262   1
# 27     2006-07-01      0  19444   1
# 28     2006-07-01      0  20258   1
# 29     2006-07-01      0  20299   1
# ...           ...    ...    ...  ..
# 20773  2006-09-30      8  15270   2
# 20774  2006-09-30      8  16805   1
# 20775  2006-09-30      8  17225   1
# 20776  2006-09-30      8  18588   4
# 20777  2006-09-30      8  19024   1
# 20778  2006-09-30      8  20401   3
# 20779  2006-09-30      8  20676   4
# 20780  2006-09-30      8  20849  14
# 20781  2006-09-30      8  21568   2
# 20782  2006-09-30      8  21844   5
# 20783  2006-09-30      8  22277   2
# 20784  2006-09-30      8  23287   6
# 20785  2006-09-30      8  25108   2
# 20786  2006-09-30      8  26201   1
# 20787  2006-09-30      8  26347   3
# 20788  2006-09-30      8  29668   1
# 20789  2006-09-30      8  29873   3
# 20790  2006-09-30      8  30099   2
# 20791  2006-09-30      8  30217  21
# 20792  2006-09-30      8  30315   9
# 20793  2006-09-30      8  31976   3
# 20794  2006-09-30      8  33070   1
# 20795  2006-09-30      8  33176   3
# 20796  2006-09-30      8  33322   1
# 20797  2006-09-30      8  35845   1
# 20798  2006-09-30      8  36351   3
# 20799  2006-09-30      8  36856   4
# 20800  2006-09-30      9   2152   1
# 20801  2006-09-30      9   8070   1
# 20802  2006-09-30      9   8075   2
#
# [20803 rows x 4 columns]

# %%
df['date_fixed'] = [pd.to_datetime(d) for d in df['date']]

# %%
df.groupby('l_ipn').plot.line(x='date_fixed', y='f', title='Connections per day per workstation')
# Out:
# l_ipn
# 0    Axes(0.125,0.2;0.775x0.68)
# 1    Axes(0.125,0.2;0.775x0.68)
# 2    Axes(0.125,0.2;0.775x0.68)
# 3    Axes(0.125,0.2;0.775x0.68)
# 4    Axes(0.125,0.2;0.775x0.68)
# 5    Axes(0.125,0.2;0.775x0.68)
# 6    Axes(0.125,0.2;0.775x0.68)
# 7    Axes(0.125,0.2;0.775x0.68)
# 8    Axes(0.125,0.2;0.775x0.68)
# 9    Axes(0.125,0.2;0.775x0.68)
# dtype: object

# %%
df.groupby('l_ipn').plot.line(x='date_fixed', y='f', title='Connections per day per workstation, seen logarithmically', logy=True)
# Out:
# l_ipn
# 0    Axes(0.125,0.2;0.775x0.68)
# 1    Axes(0.125,0.2;0.775x0.68)
# 2    Axes(0.125,0.2;0.775x0.68)
# 3    Axes(0.125,0.2;0.775x0.68)
# 4    Axes(0.125,0.2;0.775x0.68)
# 5    Axes(0.125,0.2;0.775x0.68)
# 6    Axes(0.125,0.2;0.775x0.68)
# 7    Axes(0.125,0.2;0.775x0.68)
# 8    Axes(0.125,0.2;0.775x0.68)
# 9    Axes(0.125,0.2;0.775x0.68)
# dtype: object

# %%
df.plot(kind='scatter', x='r_asn', y='f', logy=True, figsize=(50,15))

# %%
df_remote_to_connections = df.pivot_table(index='r_asn', values='f', aggfunc=len).sort_values(by='f', ascending=False)
df_remote_to_connections[:100].plot(kind='bar', title='Remote ip\'s with the most connections', figsize=(50, 15))

# %%
ips_to_remote = df.pivot_table(index='l_ipn', values='r_asn', aggfunc=len).sort_values(by='r_asn', ascending=False)

ips_to_remote.plot(kind='bar', title='Amount of remote ips a workstation connected to')
